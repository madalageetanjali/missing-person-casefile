# %% [markdown]
# # Module 6: Location Prediction
#
# CASEFILE Missing Person Investigation project — academic/synthetic data only.

# %%
import sys
sys.path.insert(0, '../src')
from prediction import run_prediction
results, best = run_prediction('../data/processed/trajectory_anomalies.csv', '../models', '../reports')
best
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:2153: UndefinedMetricWarning: 'k' (3) greater than or equal to 'n_classes' (3) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:2153: UndefinedMetricWarning: 'k' (3) greater than or equal to 'n_classes' (3) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:2153: UndefinedMetricWarning: 'k' (3) greater than or equal to 'n_classes' (3) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:2153: UndefinedMetricWarning: 'k' (3) greater than or equal to 'n_classes' (3) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [17:37:52] WARNING: /__w/xgboost/xgboost/src/learner.cc:794:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# === Model comparison ===
# random_forest: acc=0.943 f1=0.939 top1=0.9437716262975778 top3=1.0
# knn: acc=0.938 f1=0.935 top1=0.9377162629757786 top3=1.0
# xgboost: acc=0.933 f1=0.930 top1=0.9325259515570934 top3=1.0
#
# Selected best model: random_forest (highest weighted F1)
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:2153: UndefinedMetricWarning: 'k' (3) greater than or equal to 'n_classes' (3) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py:2153: UndefinedMetricWarning: 'k' (3) greater than or equal to 'n_classes' (3) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# 'random_forest'
