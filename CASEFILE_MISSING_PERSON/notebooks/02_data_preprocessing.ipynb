# %% [markdown]
# # Module 2: Data Preprocessing
#
# CASEFILE Missing Person Investigation project — academic/synthetic data only.

# %%
import sys
sys.path.insert(0, '../src')
from preprocessing import run_preprocessing
from pathlib import Path
df = run_preprocessing('../data/synthetic/synthetic_gps_trajectory.csv', '../data/processed/trajectory_clean.csv')
df.head()
# Out:
# Preprocessed 5784 rows -> ../data/processed/trajectory_clean.csv
#   user_id   latitude  longitude           timestamp  hour  day  weekday  \
# 0    U001  28.612141  77.209173 2025-01-01 00:05:41     0    1        2
# 1    U001  28.616414  77.210043 2025-01-01 00:10:54     0    1        2
# 2    U001  28.612257  77.211950 2025-01-01 00:16:37     0    1        2
# 3    U001  28.611898  77.210834 2025-01-01 00:27:13     0    1        2
# 4    U001  28.612701  77.210236 2025-01-01 00:43:46     0    1        2
#
#    month  is_weekend
# 0      1           0
# 1      1           0
# 2      1           0
# 3      1           0
# 4      1           0

# %%
df.isna().sum()
# Out:
# user_id       0
# latitude      0
# longitude     0
# timestamp     0
# hour          0
# day           0
# weekday       0
# month         0
# is_weekend    0
# dtype: int64

# %%
df.describe()
# Out:
#           latitude    longitude                   timestamp         hour  \
# count  5784.000000  5784.000000                        5784  5784.000000
# mean     28.620175    77.212873  2025-01-31 02:40:06.964903    11.456604
# min      28.592641    77.188604         2025-01-01 00:05:41     0.000000
# 25%      28.613172    77.208271         2025-01-16 01:25:30     5.000000
# 50%      28.615920    77.211064  2025-01-31 04:02:09.500000    11.000000
# 75%      28.629730    77.217681         2025-02-15 02:44:50    18.000000
# max      28.699087    77.352868         2025-03-01 23:49:56    23.000000
# std       0.010086     0.007905                         NaN     6.943301
#
#                day     weekday        month   is_weekend
# count  5784.000000  5784.00000  5784.000000  5784.000000
# mean     15.047199     3.02092     1.503804     0.281466
# min       1.000000     0.00000     1.000000     0.000000
# 25%       7.000000     1.00000     1.000000     0.000000
# 50%      15.000000     3.00000     1.000000     0.000000
# 75%      22.000000     5.00000     2.000000     1.000000
# max      31.000000     6.00000     3.000000     1.000000
# std       8.698816     1.95755     0.533815     0.449753
