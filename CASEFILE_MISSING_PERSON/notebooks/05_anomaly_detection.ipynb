# %% [markdown]
# # Module 5: Anomaly Detection
#
# CASEFILE Missing Person Investigation project — academic/synthetic data only.

# %%
import sys
sys.path.insert(0, '../src')
from anomaly_detection import run_anomaly_detection
df = run_anomaly_detection('../data/processed/trajectory_clustered.csv', '../data/processed/trajectory_anomalies.csv', '../models')
df['anomaly_consensus'].value_counts()
# Out:
# Flagged 130 / 5784 points as anomalous (consensus of >=2 methods).
# Reminder: anomaly != suspicious/criminal behavior. Document false positives.
# anomaly_consensus
# 0    5654
# 1     130
# Name: count, dtype: int64

# %% [markdown]
# **Note:** an anomaly flag means the movement statistically differs from the subject's normal pattern. It does not imply suspicious or criminal behavior. Discuss false positives/negatives and threshold choice in the final report.
