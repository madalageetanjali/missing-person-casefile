# %% [markdown]
# # Module 1: Data Collection
#
# CASEFILE Missing Person Investigation project — academic/synthetic data only.

# %% [markdown]
# This notebook documents the datasets used and generates the synthetic GPS trajectory + fictional case file used throughout the project.
#
# **Data Source Document**
# | Dataset | Source | Records | Features | License | Purpose |
# |---|---|---|---|---|---|
# | Synthetic GPS trajectory (this project) | Generated locally | ~5,700 pts | user_id, lat, lon, timestamp | N/A (synthetic) | Stand-in for GeoLife-style trajectory |
# | Microsoft GeoLife GPS Trajectory Dataset (optional, real) | https://www.microsoft.com/en-us/research/publication/geolife-gps-trajectory-dataset-user-guide/ | 17,000+ trajectories | lat, lon, altitude, date/time | Microsoft Research license (see site) | Real-world movement pattern data |
# | OpenStreetMap (optional) | https://www.openstreetmap.org/ | varies | roads, POIs | ODbL | Contextual geography |

# %%
import sys
sys.path.insert(0, '../src')
from generate_synthetic_data import main
main()
# Out:
# Wrote 5784 GPS points -> /home/claude/CASEFILE_MISSING_PERSON/data/synthetic/synthetic_gps_trajectory.csv
# Wrote case file -> /home/claude/CASEFILE_MISSING_PERSON/data/synthetic/synthetic_case_file.csv

# %%
import pandas as pd
df = pd.read_csv('../data/synthetic/synthetic_gps_trajectory.csv')
df.head()
# Out:
#   user_id   latitude  longitude            timestamp
# 0    U001  28.612141  77.209173  2025-01-01 00:05:41
# 1    U001  28.616414  77.210043  2025-01-01 00:10:54
# 2    U001  28.612257  77.211950  2025-01-01 00:16:37
# 3    U001  28.611898  77.210834  2025-01-01 00:27:13
# 4    U001  28.612701  77.210236  2025-01-01 00:43:46
